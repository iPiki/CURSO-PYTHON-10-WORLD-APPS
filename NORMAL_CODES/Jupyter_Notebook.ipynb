# %%
import pandas
df1=pandas.read_json("supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df2=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
import pandas
df3=pandas.read_csv("supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-commas.txt", header=None)
df5
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df5.columns=["si","no","no","si","no","si","no"]
df5
# Out:
#   si               no             no                si   no           si  no
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df5
# Out:
#   si               no             no                si   no           si  no
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df9=pandas.read_csv("supermarkets.csv")
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
list(df9.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df9.iloc[1:3,1:3]
# Out:
#           Address           City
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco

# %%
df9.drop("Address",axis=1)
# Out:
#    ID           City             State Country         Name  Employees
# 0   1  San Francisco          CA 94114     USA      Madeira          8
# 1   2  San Francisco          CA 94119     USA  Bready Shop         15
# 2   3  San Francisco  California 94114     USA  Super River         25
# 3   4  San Francisco          CA 94114     USA   Ben's Shop         10
# 4   5  San Francisco        California     USA      Sanchez         12
# 5   6  San Francisco          CA 94114     USA   Richvalley         20

# %%
df11
# Out:
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df11["Continent"]=df9["Name"]+","+["Continent"]
df11
# Out:
#               State Country         Name  Employees              Continent
# 0          CA 94114     USA      Madeira          8      Madeira,Continent
# 1          CA 94119     USA  Bready Shop         15  Bready Shop,Continent
# 2  California 94114     USA  Super River         25  Super River,Continent
# 3          CA 94114     USA   Ben's Shop         10   Ben's Shop,Continent
# 4        California     USA      Sanchez         12      Sanchez,Continent
# 5          CA 94114     USA   Richvalley         20   Richvalley,Continent

# %%
df11_t=df11.T
df11_t
# Out:
#                            0                      1                      2  \
# State               CA 94114               CA 94119       California 94114
# Country                  USA                    USA                    USA
# Name                 Madeira            Bready Shop            Super River
# Employees                  8                     15                     25
# Continent  Madeira,Continent  Bready Shop,Continent  Super River,Continent
#
#                               3                  4                     5
# State                  CA 94114         California              CA 94114
# Country                     USA                USA                   USA
# Name                 Ben's Shop            Sanchez            Richvalley
# Employees                    10                 12                    20
# Continent  Ben's Shop,Continent  Sanchez,Continent  Richvalley,Continent

# %%
df11_t["My address"]=["My city","My country","My name",100,"My continent"]
df11_t
# Out:
#                            0                      1                      2  \
# State               CA 94114               CA 94119       California 94114
# Country                  USA                    USA                    USA
# Name                 Madeira            Bready Shop            Super River
# Employees                  8                     15                     25
# Continent  Madeira,Continent  Bready Shop,Continent  Super River,Continent
#
#                               3                  4                     5  \
# State                  CA 94114         California              CA 94114
# Country                     USA                USA                   USA
# Name                 Ben's Shop            Sanchez            Richvalley
# Employees                    10                 12                    20
# Continent  Ben's Shop,Continent  Sanchez,Continent  Richvalley,Continent
#
#              My address
# State           My city
# Country      My country
# ...

# %%
df11=df11_t.T
df11
# Out:
#                        State     Country         Name Employees  \
# 0                   CA 94114         USA      Madeira         8
# 1                   CA 94119         USA  Bready Shop        15
# 2           California 94114         USA  Super River        25
# 3                   CA 94114         USA   Ben's Shop        10
# 4                 California         USA      Sanchez        12
# 5                   CA 94114         USA   Richvalley        20
# My address           My city  My country      My name       100
#
#                         Continent
# 0               Madeira,Continent
# 1           Bready Shop,Continent
# 2           Super River,Continent
# 3            Ben's Shop,Continent
# 4               Sanchez,Continent
# 5            Richvalley,Continent
# My address           My continent

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("3995 23rd St, California,")

# %%
import pandas
df=
